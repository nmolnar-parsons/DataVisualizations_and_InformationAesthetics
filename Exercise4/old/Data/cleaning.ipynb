# %% [markdown]
# # Data Cleaning and Processing
# Clean up production countries added
# - convert from json to csv
# - get rid of movies with no production country
# - standardize production country data

# %%
import json
import pandas as pd

# %%
#import production json
with open('Data/NetflixMovies_production_enriched.json', 'r') as f:
    production_data = json.load(f)

# %%
df = pd.DataFrame(production_data)
df.head()
# Out:
#             searched      tconst           Title Available Globally?  \
# 0  0  Back in Action  tt21191806  Back in Action                 Yes
# 1  1           STRAW  tt32550101           STRAW                 Yes
# 2  2   The Life List   tt2172954   The Life List                 Yes
# 3  3   Exterritorial  tt30876483   Exterritorial                 Yes
# 4  4           Havoc  tt14123284           Havoc                 Yes
#
#   Release Date Hours Viewed Runtime      Views    Simple_Title net_year  \
# 0   2025-01-17    313000000    1:54  164700000  Back in Action   2025.0
# 1   2025-06-06    185200000    1:48  102900000           STRAW   2025.0
# 2   2025-03-28    198900000    2:05   95500000   The Life List   2025.0
# 3   2025-04-30    159000000    1:49   87500000   Exterritorial   2025.0
# 4   2025-04-25    154900000    1:47   86900000           Havoc   2025.0
#
#   titleType    primaryTitle   originalTitle startYear runtimeMinutes  \
# 0     movie  Back in Action  Back in Action      2025            114
# 1     movie           Straw           Straw      2025            105
# 2     movie   The Life List   The Life List      2025            123
# 3     movie   Exterritorial   Exterritorial      2025            109
# 4     movie           Havoc           Havoc      2025            107
#
#                     genres                                productionCountries  \
# 0            Action,Comedy  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1           Drama,Thriller  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2     Comedy,Drama,Romance  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  Action,Mystery,Thriller  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 4       Action,Crime,Drama  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
#
#   originCountry                                           overview
# 0          [US]  Fifteen years after vanishing from the CIA to ...
# 1          [US]  What will be her last straw? A devastatingly b...
# 2          [US]  When her mother sends her on a quest to comple...
# 3      [AT, DE]  When her son vanishes inside a US consulate, e...
# 4      [US, GB]  When a drug heist swerves lethally out of cont...

# %%
df.iloc[0]["productionCountries"]
(df.iloc[0]["productionCountries"][0]["name"])
# Out:
# 'United States of America'

# %%
df.iloc[3]["productionCountries"]
# Out:
# [{'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'AT', 'name': 'Austria'}]

# %% [markdown]
# productionCountries contains a list of 1 or more dictionaries. Each dictionary contains country name and country id (iso_3166_1)

# %%
#extract country code and country names from productionCountries, add to new columns
df['CountryName'] = df['productionCountries'].apply(lambda x: [country['name'] for country in x] if isinstance(x, list) else [])

# %%
df.head()
# Out:
#             searched      tconst           Title Available Globally?  \
# 0  0  Back in Action  tt21191806  Back in Action                 Yes
# 1  1           STRAW  tt32550101           STRAW                 Yes
# 2  2   The Life List   tt2172954   The Life List                 Yes
# 3  3   Exterritorial  tt30876483   Exterritorial                 Yes
# 4  4           Havoc  tt14123284           Havoc                 Yes
#
#   Release Date Hours Viewed Runtime      Views    Simple_Title  ... titleType  \
# 0   2025-01-17    313000000    1:54  164700000  Back in Action  ...     movie
# 1   2025-06-06    185200000    1:48  102900000           STRAW  ...     movie
# 2   2025-03-28    198900000    2:05   95500000   The Life List  ...     movie
# 3   2025-04-30    159000000    1:49   87500000   Exterritorial  ...     movie
# 4   2025-04-25    154900000    1:47   86900000           Havoc  ...     movie
#
#      primaryTitle   originalTitle startYear runtimeMinutes  \
# 0  Back in Action  Back in Action      2025            114
# 1           Straw           Straw      2025            105
# 2   The Life List   The Life List      2025            123
# 3   Exterritorial   Exterritorial      2025            109
# 4           Havoc           Havoc      2025            107
#
#                     genres                                productionCountries  \
# 0            Action,Comedy  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1           Drama,Thriller  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2     Comedy,Drama,Romance  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  Action,Mystery,Thriller  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 4       Action,Crime,Drama  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
#
#   originCountry                                           overview  \
# 0          [US]  Fifteen years after vanishing from the CIA to ...
# 1          [US]  What will be her last straw? A devastatingly b...
# 2          [US]  When her mother sends her on a quest to comple...
# 3      [AT, DE]  When her son vanishes inside a US consulate, e...
# 4      [US, GB]  When a drug heist swerves lethally out of cont...
#
#                                   CountryName
# 0                  [United States of America]
# 1                  [United States of America]
# 2                  [United States of America]
# 3                          [Germany, Austria]
# 4  [United Kingdom, United States of America]
#
# [5 rows x 21 columns]

# %%
#turn runtime into minutes
type(df.iloc[0]['Runtime'])

def runtime_to_minutes(runtime):
    if isinstance(runtime, str) and ':' in runtime:
        parts = runtime.split(':')
        hours = int(parts[0])
        minutes = int(parts[1])
        return hours * 60 + minutes
    return None
df['RuntimeMinutes'] = df['Runtime'].apply(runtime_to_minutes)

# %%
df.head()
type(df.iloc[0]['RuntimeMinutes'])
# Out:
# numpy.int64

# %%
#save df to csv
df.to_csv('Data/NetflixMovies_production_cleaned.csv', index=False)
